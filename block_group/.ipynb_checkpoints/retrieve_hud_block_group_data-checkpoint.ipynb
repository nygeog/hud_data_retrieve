# %%
#GET THE SHAPEFILE OF BLOCK GROUPS IN NEW YORK STATE FROM .SHP's DBF FILE TO A CSV
import csv
from dbfpy import dbf
import os
import sys
 
filename = '/Users/danielmsheehan/Dropbox/GIS/Data/Census/census_2010/block_group/tl_2015_36_bg/tl_2015_36_bg.dbf'

if filename.endswith('.dbf'):
    print "Converting %s to csv" % filename
    csv_fn = filename[:-4]+ ".csv"
    with open(csv_fn,'wb') as csvfile:
        in_db = dbf.Dbf(filename)
        out_csv = csv.writer(csvfile)
        names = []
        for field in in_db.header.fields:
            names.append(field.name)
        out_csv.writerow(names)
        for rec in in_db:
            out_csv.writerow(rec.fieldData)
        in_db.close()
        print "Done..."
else:
  print "Filename does not end with .dbf"
#from https://gist.github.com/bertspaan/8220892
# Out:
# Converting /Users/danielmsheehan/Dropbox/GIS/Data/Census/census_2010/block_group/tl_2015_36_bg/tl_2015_36_bg.dbf to csv
# Done...

# %%
import pandas as pd 

theBlockGroupCSV = filename.replace('.dbf','.csv')

dfBlockGroup = pd.read_csv(theBlockGroupCSV)

dfBlockGroup.head(10)
# Out:
#    STATEFP  COUNTYFP  TRACTCE  BLKGRPCE         GEOID       NAMELSAD  MTFCC  \
# 0       36         5    17500         2  360050175002  Block Group 2  G5030
# 1       36         5    14100         1  360050141001  Block Group 1  G5030
# 2       36         5    14500         1  360050145001  Block Group 1  G5030
# 3       36         5     7500         2  360050075002  Block Group 2  G5030
# 4       36         5    41800         1  360050418001  Block Group 1  G5030
# 5       36         5    12500         1  360050125001  Block Group 1  G5030
# 6       36         5    12701         2  360050127012  Block Group 2  G5030
# 7       36         5     5400         3  360050054003  Block Group 3  G5030
# 8       36         5     2701         1  360050027011  Block Group 1  G5030
# 9       36         5    45800         1  360050458001  Block Group 1  G5030
#
#   FUNCSTAT   ALAND  AWATER   INTPTLAT   INTPTLON
# 0        S   23694       0  40.829633 -73.915204
# 1        S   55934       0  40.824544 -73.913121
# 2        S   47026       0  40.830982 -73.905087
# 3        S  109058       0  40.820239 -73.908068
# 4        S  140793       0  40.898919 -73.856443
# 5        S   99419       0  40.828105 -73.892652
# 6        S   67478       0  40.825368 -73.893382
# 7        S   57695       0  40.829637 -73.882437
# 8        S   39342       0  40.804488 -73.915727
# 9        S   82449       0  40.887092 -73.843590

# %%
import json
import urllib2
from pprint import pprint

listOfGeoids = dfBlockGroup["GEOID"].tolist()

variablesWanted = ['GEOID','TRANSIT_INDEX']

df = pd.DataFrame(columns=variablesWanted)

variablesURL = '%2C'.join(variablesWanted)

urlPart1 = 'http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27'
urlPart3 = '%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields='
urlPart5 = '&f=pjson'

for i in listOfGeoids:
    #print i
    i = str(i)
    urlPart2 = i
    urlPart4 = variablesURL
    
    theURL = urlPart1 + urlPart2 + urlPart3+ urlPart4 + urlPart5
    print theURL
    
    data = json.load(urllib2.urlopen(theURL))
    
    pprint(data)
    
    try:
        jsonGeoid = data[u'features'][0][u'attributes'][u'GEOID']
        jsonTransit_index = data[u'features'][0][u'attributes'][u'transit_index']
    
    except:
        jsonGeoid = i
        jsonTransit_index = -999
        
    print 'BlockGroup: ' + str(jsonGeoid) + ' - the transit index is: ' + str(jsonTransit_index)
    
    dfAppend = pd.DataFrame([[jsonGeoid, jsonTransit_index]], columns=columns) 
    df = df.append(dfAppend)
       
print df.head(10)
# Out:
# 360050175002
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360050175002%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360050175002',
#                                 u'transit_index': 100}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360050175002 100
# 360050141001
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360
}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360811008024 80
# 360811010020
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360811010020%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360811010020',
#                                 u'transit_index': None}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360811010020 None
# 360810998021
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360810998021%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360810998021',
#                                 u'transit_index': 1}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360810998021 1
# 360810997050
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360810997050%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360810997050',
#                                 u'transit_index': None}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360810997050 None
# 360811008010
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360811008010%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360811008010',
#                                 u'transit_index': None}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360811008010 None
# 360811008012
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360811008012%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360811008012',
#                                 u'transit_index': 1}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360811008012 1
# 360811008020
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360811008020%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360811008020',
#                                 u'transit_index': None}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360811008020 None
# 360811017007
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360811017007%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360811017007',
#                                 u'transit_index': 90}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360811017007 90
# 360811032023
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360811032023%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360811032023',
#                                 u'transit_index': 90}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360811032023 90
# 360811032024
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360811032024%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [{u'attributes': {u'GEOID': u'360811032024',
#                                 u'transit_index': 90}}],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# 360811032024 90
# 360811093000
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360811093000%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
# {u'displayFieldName': u'NAME',
#  u'features': [],
#  u'fieldAliases': {u'GEOID': u'GEOID', u'transit_index': u'transit_index'},
#  u'fields': [{u'alias': u'GEOID',
#               u'length': 12,
#               u'name': u'GEOID',
#               u'type': u'esriFieldTypeString'},
#              {u'alias': u'transit_index',
#               u'name': u'transit_index',
#               u'type': u'esriFieldTypeSmallInteger'}]}
# -------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-423148d4d597> in <module>()
#      29
#      30     print '-------'
# ---> 31     jsonGeoid = data[u'features'][0][u'attributes'][u'GEOID']
#      32     jsonTransit_index = data[u'features'][0][u'attributes'][u'transit_index']
#      33
#
# IndexError: list index out of range

# %%
df.to_csv('data/geoid_hud_transit_index.csv',index=False)

print df.head(1200)
# Out:
#            GEOID  TRANSIT_INDEX
# 0   360050175002            100
# 0   360050141001              1
# 0   360050145001              1
# 0   360050075002              1
# 0   360050418001             90
# 0   360050125001              1
# 0   360050127012              1
# 0   360050054003              1
# 0   360050027011              1
# 0   360050458001              1
# 0   360050224011             90
# 0   361032010044              1
# 0   361031907073              1
# 0   361031587083              1
# 0   361031585022              1
# 0   360050389001              1
# 0   360050071002              1
# 0   360050211003              1
# 0   360050197001              1
# 0   361031908004              1
# 0   361031122064              1
# 0   361031697044              1
# 0   361031697045              1
# 0   361031697046              1
# 0   361031594103              1
# 0   361031589003              1
# 0   361190127002              1
# 0   361190107011              1
# 0   361190123011              1
# 0   361190132022              1
# ..           ...            ...
# 0   361031470041              1
# 0   361032010033              1
# 0   361031699024              1
# 0   361031591052              1
# 0   361031907062              1
# 0   361032010015              1
# 0   361031466061              1
# 0   361031584022              1
# 0   361190146052             70
# 0   361190004014             90
# 0   361190004024             80
# 0   361190008015             70
# 0   361190015034            NaN
# 0   361190021044              1
# 0   361190022032             70
# 0   361190024022             90
# 0   361190024023             90
# 0   361190042003             70
# 0   361190048005             90
# 0   361190057014             70
# 0   360811008024             80
# 0   360811010020            NaN
# 0   360810998021              1
# 0   360810997050            NaN
# 0   360811008010            NaN
# 0   360811008012              1
# 0   360811008020            NaN
# 0   360811017007             90
# 0   360811032023             90
# 0   360811032024             90
#
# [274 rows x 2 columns]

# %% [markdown]
# Example of a URL getting data from: WHERE GEOID = 360593028004
#
# http://egis.hud.gov/ArcGIS/rest/services/oshc/Fhea/MapServer/5/query?text=&geometry=&geometryType=esriGeometryPoint&inSR=&spatialRel=esriSpatialRelIntersects&relationParam=&objectIds=&where=GEOID+%3D+%27360593028004%27&time=&returnCountOnly=false&returnIdsOnly=false&returnGeometry=false&maxAllowableOffset=&outSR=&outFields=GEOID%2CTRANSIT_INDEX&f=pjson
